# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('oau-books.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2954 entries, 0 to 2953
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2954 non-null   int64
#  1   Title            2953 non-null   object
#  2   Author           2380 non-null   object
#  3   Link             2953 non-null   object
#  4   Publisher        2926 non-null   object
#  5   Year             2920 non-null   object
#  6   Pages            1635 non-null   float64
#  7   Format           2945 non-null   object
#  8   Literary Form    2945 non-null   object
#  9   Library          2839 non-null   object
#  10  Items Available  2839 non-null   float64
#  11  Call Number      2839 non-null   object
#  12  Edition          793 non-null    object
#  13  ISBN             0 non-null      float64
#  14  Material Type    2954 non-null   object
#  15  Image URL        2954 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 369.4+ KB

# %%
data = pd.read_csv('oau-books.csv')
def clean_pages(p):
    if pd.isna(p):
        return np.nan
    match = re.search(r'(\d+)', str(p))
    if match:
        return int(match.group(1))
    return np.nan
data['Pages'] = data['Pages'].apply(clean_pages)

# Fill missing Author, Publisher, Year with "Unknown"
data['Author'] = data['Author'].fillna("Unknown")
data['Publisher'] = data['Publisher'].fillna("Unknown")
data['Year'] = data['Year'].fillna("Unknown")

# Droping ISBN column for all NaN
if 'ISBN' in data.columns and data['ISBN'].isnull().all():
    data.drop(columns=['ISBN'], inplace=True)

# Strip whitespace and title-case Title and Author
data['Title'] = data['Title'].str.strip().str.title()
data['Author'] = data['Author'].str.strip().str.title()

# Remove duplicates by Title + Author
data = data.drop_duplicates(subset=['Title', 'Author'])

# Save cleaned file (optional)
data.to_csv('oau-books-cleaned.csv', index=False)

print("Data cleaned! Sample rows:")
print(data.head())
# Out:
# Data cleaned! Sample rows:
#    No                                              Title  \
# 0   1  International Migration In And From Africa :  ...
# 1   2  Autering Nollywood :Critical Perspective On Th...
# 2   3  In Person--Achebe, Awoonor, And Soyinka At The...
# 3   4  Linguistics: An Introduction To Language And C...
# 4   5  Africa’S Future, Africa’S Challenge :Early Chi...
#
#                                               Author  \
# 0         Edited By Adepoju, Aderanti  Hammar, Tomas
# 1                                            Unknown
# 2  Achebe, Chinuaawoonor, Kofi, 1935-2013Soyinka,...
# 3                                   Akmajian, Adrian
# 4  (Edited By) Garcia   Marito (Edited By) Pence ...
#
#                                                 Link  \
# 0  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 1  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 3  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 4  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                                            Publisher    Year  Pages   Format  \
# 0  Population, Human Resources and  Development i...    1996  198.0  ; print
# 1                                   University Press    2014  457.0  ; print
# 2  African Studies Program, Institute for Compara...  [1975]    NaN  ; print
# 3                                      PHI Learning,    2010  630.0  ; print
# 4                                     The World Bank    2008  525.0  ; print
#
#    Literary Form                         Library  Items Available  \
# 0  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
# 1  ; Not fiction                 Arts Library(5)              5.0
# 2  ; Not fiction                             NaN              NaN
# 3  ; Not fiction  Hezekiah Oluwasanmi Library(3)              3.0
# 4  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
#
#         Call Number  Edition Material Type  \
# 0      JV8790 .In8.      NaN          Text
# 1  PN1998. Au8, ...      NaN          Text
# 2               NaN      NaN          Text
# 3    P121 .Ak5, ...  6th ed.          Text
# 4     HQ778.7 .Af8.      NaN          Text
#
#                                            Image URL
# 0  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 1  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 3  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 4  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...

# %%
data.head ()
# Out:
#    No                                              Title  \
# 0   1  International Migration In And From Africa :  ...
# 1   2  Autering Nollywood :Critical Perspective On Th...
# 2   3  In Person--Achebe, Awoonor, And Soyinka At The...
# 3   4  Linguistics: An Introduction To Language And C...
# 4   5  Africa’S Future, Africa’S Challenge :Early Chi...
#
#                                               Author  \
# 0         Edited By Adepoju, Aderanti  Hammar, Tomas
# 1                                            Unknown
# 2  Achebe, Chinuaawoonor, Kofi, 1935-2013Soyinka,...
# 3                                   Akmajian, Adrian
# 4  (Edited By) Garcia   Marito (Edited By) Pence ...
#
#                                                 Link  \
# 0  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 1  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 3  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 4  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                                            Publisher    Year  Pages   Format  \
# 0  Population, Human Resources and  Development i...    1996  198.0  ; print
# 1                                   University Press    2014  457.0  ; print
# 2  African Studies Program, Institute for Compara...  [1975]    NaN  ; print
# 3                                      PHI Learning,    2010  630.0  ; print
# 4                                     The World Bank    2008  525.0  ; print
#
#    Literary Form                         Library  Items Available  \
# 0  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
# 1  ; Not fiction                 Arts Library(5)              5.0
# 2  ; Not fiction                             NaN              NaN
# 3  ; Not fiction  Hezekiah Oluwasanmi Library(3)              3.0
# 4  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
#
#         Call Number  Edition Material Type  \
# 0      JV8790 .In8.      NaN          Text
# 1  PN1998. Au8, ...      NaN          Text
# 2               NaN      NaN          Text
# 3    P121 .Ak5, ...  6th ed.          Text
# 4     HQ778.7 .Af8.      NaN          Text
#
#                                            Image URL
# 0  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 1  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 3  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 4  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...

# %%
data.tail(100)
# Out:
#         No                                              Title  \
# 2854  2855  Architecture, You And Me : The Diary Of A Deve...
# 2855  2856  A History Of Spanish Painting/Chandler Rathfon...
# 2856  2857  A History Of Spanish Painting : Volumevi-Part ...
# 2857  2858  Musical Iconography :A Manaual For Cataloguing...
# 2858  2859  American Architecure And Other Writings/Montgo...
# ...    ...                                                ...
# 2949  2950  Professional Mathematics For Polytechnics For ...
# 2950  2951  Biotechnology And Insect Pest Managementdaxton...
# 2951  2952  Building Constructionxvi, 938P.: Illit Include...
# 2952  2953  Basic Of Biotechnology In Agricultureethan Dic...
# 2953  2954  Introduction To Operations Research/Frederick ...
#
#                                       Author  \
# 2854                              Giedion, S
# 2855                  Post, Chandler Rathfon
# 2856                  Post, Chandler Rathfon
# 2857                      Brown,Howard Mayer
# 2858                    Schuyler, Montgomery
# ...                                      ...
# 2949                               Dass, H.K
# 2950                            Ware, Daxton
# 2951                           Jha, Janardan
# 2952                        Dickinson, Ethan
# 2953  Hiller, Frederick S. Lieberman, Gerald
#
#                                                    Link  \
# 2854  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2855  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2856  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2857  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2858  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# ...                                                 ...
# 2949  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2950  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2951  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2952  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2953  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                      Publisher  Year   Pages   Format  Literary Form  \
# 2854   Harvard Unversity Press  2013   221.0  ; print  ; Not fiction
# 2855  Harvard University Press  2013   354.0  ; print  ; Not fiction
# 2856  Harvard University Press  2013   334.0  ; print  ; Not fiction
# 2857  Harvard University Press  2013   220.0  ; print  ; Not fiction
# 2858  Harvard University Press  2013   664.0  ; print  ; Not fiction
# ...                        ...   ...     ...      ...            ...
# 2949            CBS Publishers  2017   348.0  ; print  ; Not fiction
# 2950             ED-Tech Press  2022   292.0  ; print  ; Not fiction
# 2951         Khanna Publishers  2017   938.0  ; print  ; Not fiction
# 2952      White Press Academic  2022   291.0  ; print  ; Not fiction
# 2953               McGraw-Hill  2015  1010.0  ; print  ; Not fiction
#
#                              Library  Items Available     Call Number Edition  \
# 2854                  EDM Library(1)              1.0      N7445.G36.     NaN
# 2855                  EDM Library(1)              1.0      ND801.P84.     NaN
# 2856                  EDM Library(1)              1.0      ND801.P84.     NaN
# 2857                 Arts Library(1)              1.0      ML111.B78.     NaN
# 2858                  EDM Library(1)              1.0     NA710.Sch1.     NaN
# ...                              ...              ...             ...     ...
# 2949  Hezekiah Oluwasanmi Library(1)              1.0       QA39.D26.     NaN
# 2950  Hezekiah Oluwasanmi Library(1)              1.0      SB933.W22.     NaN
# 2951                  EDM Library(3)              3.0  TH145.J55, ...     NaN
# 2952  Hezekiah Oluwasanmi Library(1)              1.0     S494.5.D56.     NaN
# 2953  Hezekiah Oluwasanmi Library(1)              1.0       Q175.H55.    10th
#
#      Material Type                                          Image URL
# 2854          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2855          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2856          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2857          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2858          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# ...            ...                                                ...
# 2949          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2950          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2951          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2952          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2953          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
#
# [100 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2917 entries, 0 to 2953
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2917 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2917 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2917 non-null   object
#  5   Year             2917 non-null   object
#  6   Pages            1613 non-null   float64
#  7   Format           2908 non-null   object
#  8   Literary Form    2908 non-null   object
#  9   Library          2816 non-null   object
#  10  Items Available  2816 non-null   float64
#  11  Call Number      2816 non-null   object
#  12  Edition          778 non-null    object
#  13  Material Type    2917 non-null   object
#  14  Image URL        2917 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 364.6+ KB

# %%
data = pd.read_csv("oau-books-cleaned.csv")

# %%
data.head()
# Out:
#    No                                              Title  \
# 0   1  International Migration In And From Africa :  ...
# 1   2  Autering Nollywood :Critical Perspective On Th...
# 2   3  In Person--Achebe, Awoonor, And Soyinka At The...
# 3   4  Linguistics: An Introduction To Language And C...
# 4   5  Africa’S Future, Africa’S Challenge :Early Chi...
#
#                                               Author  \
# 0         Edited By Adepoju, Aderanti  Hammar, Tomas
# 1                                            Unknown
# 2  Achebe, Chinuaawoonor, Kofi, 1935-2013Soyinka,...
# 3                                   Akmajian, Adrian
# 4  (Edited By) Garcia   Marito (Edited By) Pence ...
#
#                                                 Link  \
# 0  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 1  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 3  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 4  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                                            Publisher    Year  Pages   Format  \
# 0  Population, Human Resources and  Development i...    1996  198.0  ; print
# 1                                   University Press    2014  457.0  ; print
# 2  African Studies Program, Institute for Compara...  [1975]    NaN  ; print
# 3                                      PHI Learning,    2010  630.0  ; print
# 4                                     The World Bank    2008  525.0  ; print
#
#    Literary Form                         Library  Items Available  \
# 0  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
# 1  ; Not fiction                 Arts Library(5)              5.0
# 2  ; Not fiction                             NaN              NaN
# 3  ; Not fiction  Hezekiah Oluwasanmi Library(3)              3.0
# 4  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
#
#         Call Number  Edition Material Type  \
# 0      JV8790 .In8.      NaN          Text
# 1  PN1998. Au8, ...      NaN          Text
# 2               NaN      NaN          Text
# 3    P121 .Ak5, ...  6th ed.          Text
# 4     HQ778.7 .Af8.      NaN          Text
#
#                                            Image URL
# 0  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 1  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 3  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 4  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2917 entries, 0 to 2916
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2917 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2917 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2917 non-null   object
#  5   Year             2917 non-null   object
#  6   Pages            1613 non-null   float64
#  7   Format           2908 non-null   object
#  8   Literary Form    2908 non-null   object
#  9   Library          2816 non-null   object
#  10  Items Available  2816 non-null   float64
#  11  Call Number      2816 non-null   object
#  12  Edition          778 non-null    object
#  13  Material Type    2917 non-null   object
#  14  Image URL        2917 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 342.0+ KB

# %%
# Drop rows with missing Title or Author
data = data.dropna(subset=['Title', 'Author'])

# %%
# Remove exact duplicate books based on Title and Author
data = data.drop_duplicates(subset=['Title', 'Author'])

# %%
# Fill missing categorical columns with "Unknown"
for col in ['Format', 'Literary Form', 'Library', 'Edition']:
    data[col] = data[col].fillna('Unknown')

# %%
data = data.reset_index(drop=True)

# Print info and head to confirm cleaning
print(data.info())
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2916 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2916 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2916 non-null   object
#  5   Year             2916 non-null   object
#  6   Pages            1613 non-null   float64
#  7   Format           2916 non-null   object
#  8   Literary Form    2916 non-null   object
#  9   Library          2916 non-null   object
#  10  Items Available  2816 non-null   float64
#  11  Call Number      2816 non-null   object
#  12  Edition          2916 non-null   object
#  13  Material Type    2916 non-null   object
#  14  Image URL        2916 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 341.8+ KB
# None
#    No                                              Title  \
# 0   1  International Migration In And From Africa :  ...
# 1   2  Autering Nollywood :Critical Perspective On Th...
# 2   3  In Person--Achebe, Awoonor, And Soyinka At The...
# 3   4  Linguistics: An Introduction To Language And C...
# 4   5  Africa’S Future, Africa’S Challenge :Early Chi...
#
#                                               Author  \
# 0         Edited By Adepoju, Aderanti  Hammar, Tomas
# 1                                            Unknown
# 2  Achebe, Chinuaawoonor, Kofi, 1935-2013Soyinka,...
# 3                                   Akmajian, Adrian
# 4  (Edited By) Garcia   Marito (Edited By) Pence ...
#
#                                                 Link  \
# 0  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 1  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 3  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 4  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                                            Publisher    Year  Pages   Format  \
# 0  Population, Human Resources and  Development i...    1996  198.0  ; print
# 1                                   University Press    2014  457.0  ; print
# 2  African Studies Program, Institute for Compara...  [1975]    NaN  ; print
# 3                                      PHI Learning,    2010  630.0  ; print
# 4                                     The World Bank    2008  525.0  ; print
#
#    Literary Form                         Library  Items Available  \
# 0  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
# 1  ; Not fiction                 Arts Library(5)              5.0
# 2  ; Not fiction                         Unknown              NaN
# 3  ; Not fiction  Hezekiah Oluwasanmi Library(3)              3.0
# 4  ; Not fiction  Hezekiah Oluwasanmi Library(1)              1.0
#
#         Call Number  Edition Material Type  \
# 0      JV8790 .In8.  Unknown          Text
# 1  PN1998. Au8, ...  Unknown          Text
# 2               NaN  Unknown          Text
# 3    P121 .Ak5, ...  6th ed.          Text
# 4     HQ778.7 .Af8.  Unknown          Text
#
#                                            Image URL
# 0  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 1  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 3  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 4  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2916 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2916 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2916 non-null   object
#  5   Year             2916 non-null   object
#  6   Pages            1613 non-null   float64
#  7   Format           2916 non-null   object
#  8   Literary Form    2916 non-null   object
#  9   Library          2916 non-null   object
#  10  Items Available  2816 non-null   float64
#  11  Call Number      2816 non-null   object
#  12  Edition          2916 non-null   object
#  13  Material Type    2916 non-null   object
#  14  Image URL        2916 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 341.8+ KB

# %%
print(data['Pages'].isnull().sum())  
data['Pages'] = data['Pages'].fillna(0)
print(data['Pages'].isnull().sum())
# Out:
# 1303
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2916 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2916 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2916 non-null   object
#  5   Year             2916 non-null   object
#  6   Pages            2916 non-null   float64
#  7   Format           2916 non-null   object
#  8   Literary Form    2916 non-null   object
#  9   Library          2916 non-null   object
#  10  Items Available  2816 non-null   float64
#  11  Call Number      2816 non-null   object
#  12  Edition          2916 non-null   object
#  13  Material Type    2916 non-null   object
#  14  Image URL        2916 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 341.8+ KB

# %%
data['Items Available'] = data['Items Available'].fillna(0)
data['Call Number'] = data['Call Number'].fillna('Unknown')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               2916 non-null   int64
#  1   Title            2916 non-null   object
#  2   Author           2916 non-null   object
#  3   Link             2916 non-null   object
#  4   Publisher        2916 non-null   object
#  5   Year             2916 non-null   object
#  6   Pages            2916 non-null   float64
#  7   Format           2916 non-null   object
#  8   Literary Form    2916 non-null   object
#  9   Library          2916 non-null   object
#  10  Items Available  2916 non-null   float64
#  11  Call Number      2916 non-null   object
#  12  Edition          2916 non-null   object
#  13  Material Type    2916 non-null   object
#  14  Image URL        2916 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 341.8+ KB

# %%
data.to_csv('oau_books_cleaned2.csv', index=False, encoding='utf-8')

# %%
data.head(20)
# Out:
#     No                                              Title  \
# 0    1  International Migration In And From Africa :  ...
# 1    2  Autering Nollywood :Critical Perspective On Th...
# 2    3  In Person--Achebe, Awoonor, And Soyinka At The...
# 3    4  Linguistics: An Introduction To Language And C...
# 4    5  Africa’S Future, Africa’S Challenge :Early Chi...
# 5    6  Shakespeare In & Out Of Africavol. Editor, Jan...
# 6    7  The Encylopedia Americana:  Complete In Thirty...
# 7    8  Settled Strangers Asian Business Elites In Eas...
# 8    9  New Architecture On Indigenous Landsjoy Monice...
# 9   10  Achieving Your Assessor And Quality Assurance ...
# 10  11  Contemporary  Womenedited By Jane Plastow & Yv...
# 11  12  Narrative Network:  Stories Approach In A Digi...
# 12  13  Qur’An And Astronomy [A Comparative Analysis]M...
# 13  14  African Theatre Shakespeare In And Out Of Afri...
# 14  15  Mathematics Education With Digital Technologya...
# 15  16  The History Of Africa: The Quest For Eternal H...
# 16  17  Shakespeare In & Out Of Africa / 12) . Xiv,194...
# 17  18  Understanding Research With Children And Young...
# 18  19  Archtectural Atmosphere On The Experience And ...
# 19  20  Advocacy In English Language Teaching And Lear...
#
#                                                Author  \
# 0          Edited By Adepoju, Aderanti  Hammar, Tomas
# 1                                             Unknown
# 2   Achebe, Chinuaawoonor, Kofi, 1935-2013Soyinka,...
# 3                                    Akmajian, Adrian
# 4   (Edited By) Garcia   Marito (Edited By) Pence ...
# 5                        Plastow, Jane Banham, Martin
# 6                                             Unknown
# 7                                      Oonk, Gijsbert
# 8                                  Malnar, Joy Monice
# 9                                       Gravells, Ann
# 10       Edited By Plastow, Jane And Hutchison Yvette
# 11                                     Alleyne, Brian
# 12                             Nayayi, Muhammad Lawal
# 13                                            Unknown
# 14                   Aairan Oldknow And Carol Knights
# 15                                 Asante,Molefi Kete
# 16                                            Unknown
# 17                          Clark,  Alison....[Et Al]
# 18                                  Barch , Christian
# 19                                            Unknown
#
#                                                  Link  \
# 0   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 1   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 2   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 3   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 4   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 5   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 6   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 7   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 8   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 9   https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 10  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 11  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 12  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 13  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 14  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 15  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 16  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 17  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 18  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
# 19  https://opac.oauife.edu.ng/cgi-bin/koha/opac-d...
#
#                                             Publisher    Year  Pages   Format  \
# 0   Population, Human Resources and  Development i...    1996  198.0  ; print
# 1                                    University Press    2014  457.0  ; print
# 2   African Studies Program, Institute for Compara...  [1975]    0.0  ; print
# 3                                       PHI Learning,    2010  630.0  ; print
# 4                                      The World Bank    2008  525.0  ; print
# 5                                         James Curry    2013  194.0  ; print
# 6                               Americana Corporation    1952  806.0  ; print
# 7                                                SAGE    2013  270.0  ; print
# 8                       University of Minnesota Press    2013    0.0  ; print
# 9                                  Sage Publications,    2014  274.0  ; print
# 10                                       James Currey    2015    0.0  ; print
# 11                                 Sage Publications,    2015  207.0  ; print
# 12                      Ahmadu Bello University Press    2015    0.0  ; print
# 13                                     : James Currey  , 2013  194.0  ; print
# 14             P.C.M Education and digital Technology    2013    0.0  ; print
# 15                                          Routledge    2019    0.0  ; print
# 16                                            Unknown    2013  194.0  ; print
# 17                                               SAGE    2014  309.0  ; print
# 18                            German National library    2014  111.0  ; print
# 19                                          Routledge    2019    0.0  ; print
#
#     Literary Form                          Library  Items Available  \
# 0   ; Not fiction   Hezekiah Oluwasanmi Library(1)              1.0
# 1   ; Not fiction                  Arts Library(5)              5.0
# 2   ; Not fiction                          Unknown              0.0
# 3   ; Not fiction   Hezekiah Oluwasanmi Library(3)              3.0
# 4   ; Not fiction   Hezekiah Oluwasanmi Library(1)              1.0
# 5   ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 6   ; Not fiction  Hezekiah Oluwasanmi Library(45)             45.0
# 7   ; Not fiction             Education Library(1)              1.0
# 8   ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 9   ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 10  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 11  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 12  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 13  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 14  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 15  ; Not fiction   Hezekiah Oluwasanmi Library(3)              3.0
# 16  ; Not fiction                  Arts Library(1)              1.0
# 17  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 18  ; Not fiction   Hezekiah Oluwasanmi Library(2)              2.0
# 19  ; Not fiction                  Arts Library(1)              1.0
#
#              Call Number                                            Edition  \
# 0           JV8790 .In8.                                            Unknown
# 1       PN1998. Au8, ...                                            Unknown
# 2                Unknown                                            Unknown
# 3         P121 .Ak5, ...                                            6th ed.
# 4          HQ778.7 .Af8.                                            Unknown
# 5    PR3109.A35Sh53, ...                                            Unknown
# 6          AE5 .En1, ...                                            Unknown
# 7          DT16 .E17On4.                                            Unknown
# 8   NA 2543 .A58M31, ...                                            Unknown
# 9     LC5225.A75G78, ...                                            2nd ed.
# 10      PN2969 .C74, ...                                            Unknown
# 11     H61.295 .Al5, ...                                            Unknown
# 12     BP134 .A8N23, ...                                            Unknown
# 13      PR3109 .Af8, ...                                            Unknown
# 14      QA 11.2.Ad8, ...                                            Unknown
# 15          DT20.A2, ...                                        3rd Edition
# 16     PR3109S .A35Sh53.  volume editor, Jane Plastow: reviews editor, M...
# 17    HQ767.85 .Un2, ...                                            Unknown
# 18       NA 203.B23, ...                                            Unknown
# 19         PE1128.A2Ad9.                                            Unknown
#
#    Material Type                                          Image URL
# 0           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 1           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 2           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 3           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 4           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 5           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 6           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 7           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 8           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 9           Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 10          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 11          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 12          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 13          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 14          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 15          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 16          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 17          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 18          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
# 19          Text  https://opac.oauife.edu.ng/opac-tmpl/lib/famfa...
